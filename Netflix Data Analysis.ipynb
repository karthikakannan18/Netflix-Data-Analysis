# %% [markdown]
# # NETFLIX DATA ANALYSIS

# %%
#importing datasets 
import pandas as pd
data = pd.read_csv("netflix_dataset.csv")

# %%
data
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
data.tail()
# Out:
#      show_id     type                                    title     director  \
# 7782   s7783    Movie                                     Zozo  Josef Fares
# 7783   s7784    Movie                                   Zubaan  Mozez Singh
# 7784   s7785    Movie                        Zulu Man in Japan          NaN
# 7785   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast  \
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                            Nasty C
# 7785                         Adriano Zumbo, Rachel Khoo
# 7786                                                NaN
#
#                                                 country          date_added  \
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
data.shape
# Out:
# (7787, 12)

# %%
data.size
# Out:
# 93444

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
data.shape
# Out:
# (7787, 12)

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7782    False
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# Length: 7787, dtype: bool

# %%
data.drop_duplicates(inplace = True)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.shape
# Out:
# (7787, 12)

# %%
#Checking if there is any null value 
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False      True  False    False       False
# 1       False  False  False     False  False    False       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False    False       False
# 4       False  False  False     False  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 7782    False  False  False     False  False    False       False
# 7783    False  False  False     False  False    False       False
# 7784    False  False  False      True  False     True       False
# 7785    False  False  False      True  False    False       False
# 7786    False  False  False     False   True    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
#Finding the show_id and director of the show never have I ever
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
data[data['title'].isin(['The Good Place'])]
# Out:
#      show_id     type           title director  \
# 6405   s6406  TV Show  The Good Place      NaN
#
#                                                    cast        country  \
# 6405  Kristen Bell, Ted Danson, William Jackson Harp...  United States
#
#               date_added  release_year rating   duration    listed_in  \
# 6405  September 26, 2020          2020  TV-14  4 Seasons  TV Comedies
#
#                                             description
# 6405  Due to an error, self-absorbed Eleanor Shellst...

# %%
data[data['title'].str.contains('The Good Place')]
# Out:
#      show_id     type           title director  \
# 6405   s6406  TV Show  The Good Place      NaN
#
#                                                    cast        country  \
# 6405  Kristen Bell, Ted Danson, William Jackson Harp...  United States
#
#               date_added  release_year rating   duration    listed_in  \
# 6405  September 26, 2020          2020  TV-14  4 Seasons  TV Comedies
#
#                                             description
# 6405  Due to an error, self-absorbed Eleanor Shellst...

# %%
#Finding out the year in which the highest number of movies and TV shows were released
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data['Date_N'] = pd.to_datetime(data['date_added'])

# %%
data.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#Show all the movies released in the year 2019
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data['release_year']=data['Date_N'].dt.year

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020        2020.0  TV-MA  4 Seasons
# 1  December 23, 2016        2016.0  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
data[(data['type'] == 'Movie') & (data['release_year']== 2019)]
# Out:
#      show_id   type                     title  \
# 7         s8  Movie                       187
# 8         s9  Movie                       706
# 13       s14  Movie                     2,215
# 15       s16  Movie                    Oct-01
# 18       s19  Movie                    15-Aug
# ...      ...    ...                       ...
# 7769   s7770  Movie  Zindagi Na Milegi Dobara
# 7773   s7774  Movie            Zoé: Panoramas
# 7774   s7775  Movie                    Zodiac
# 7778   s7779  Movie                Zombieland
# 7783   s7784  Movie                    Zubaan
#
#                                    director  \
# 7                            Kevin Reynolds
# 8                             Shravan Kumar
# 13                      Nottapon Boonprakob
# 15                           Kunle Afolayan
# 18                       Swapnaneel Jayakar
# ...                                     ...
# 7769                            Zoya Akhtar
# 7773  Rodrigo Guardiola, Gabriel Cruz Rivas
# ...

# %%
#Showing only the titles of TV Shows that were released in South Korea only 
data[(data['type'] == 'TV Show') & (data['country']== 'South Korea')]
# Out:
#      show_id     type                        title director  \
# 51       s52  TV Show           100 Days My Prince      NaN
# 61       s62  TV Show             12 Years Promise      NaN
# 95       s96  TV Show                     28 Moons      NaN
# 191     s192  TV Show             A Korean Odyssey      NaN
# 199     s200  TV Show          A Love So Beautiful      NaN
# ...      ...      ...                          ...      ...
# 7555   s7556  TV Show  What in the World Happened?      NaN
# 7583   s7584  TV Show     When the Camellia Blooms      NaN
# 7601   s7602  TV Show                 White Nights      NaN
# 7711   s7712  TV Show    YG Future Strategy Office      NaN
# 7720   s7721  TV Show         YooHoo to the Rescue      NaN
#
#                                                    cast      country  \
# 51    Doh Kyung-soo, Nam Ji-hyun, Cho Seong-ha, Cho ...  South Korea
# 61    So-yeon Lee, Namkoong Min, Tae-im Lee, So-hui ...  South Korea
# ...

# %%
data[(data['type'] == 'TV Show') & (data['country']== 'South Korea')] ['title']
# Out:
# 51               100 Days My Prince
# 61                 12 Years Promise
# 95                         28 Moons
# 191                A Korean Odyssey
# 199             A Love So Beautiful
#                    ...
# 7555    What in the World Happened?
# 7583       When the Camellia Blooms
# 7601                   White Nights
# 7711      YG Future Strategy Office
# 7720           YooHoo to the Rescue
# Name: title, Length: 147, dtype: object

# %%
#Showing top 20 directors , who gave highest number of TV Shows & Movies to Netflix
data['director'].value_counts().head(20)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Ryan Polito                8
# Robert Rodriguez           8
# Kunle Afolayan             8
# Hakan Algül                8
# Shannon Hartman            8
# Johnnie To                 8
# Quentin Tarantino          8
# Lance Bangs                8
# Don Michael Paul           7
# McG                        7
# Justin G. Dyck             7
# Name: director, dtype: int64

# %%
#Showing the data where category is Movie and type is comedies or country is United Kingdom
data[(data['type'] == 'Movie') & (data['listed_in']== 'Comedies')]
# Out:
#      show_id   type                        title                director  \
# 33       s34  Movie                 #realityhigh        Fernando Lebrija
# 72       s73  Movie                     17 Again             Burr Steers
# 84       s85  Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149  Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175  Movie  A Futile and Stupid Gesture              David Wain
# ...      ...    ...                          ...                     ...
# 7339   s7340  Movie         Undercover Brother 2            Leslie Small
# 7588   s7589  Movie            Where's the Money         Scott Zabielski
# 7621   s7622  Movie                    Wild Oats            Andy Tennant
# 7632   s7633  Movie                 Wine Country             Amy Poehler
# 7662   s7663  Movie                      Work It           Laura Terruso
#
#                                                    cast  \
# ...

# %%
data[(data['type'] == 'Movie') & (data['listed_in']== 'Comedies') | (data['country'] == 'United Kingdom')]
# Out:
#      show_id     type                   title          director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7668   s7669  TV Show  World War II in Colour               NaN
# 7669   s7670  TV Show  World's Busiest Cities               NaN
# 7686   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7723   s7724    Movie            You Can Tutu       James Brown
# 7738   s7739  TV Show         Young Wallander               NaN
#
#                                                    cast         country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
#In how many movies/shows, Tom Cruise was cast
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020        2020.0  TV-MA  4 Seasons
# 1  December 23, 2016        2016.0  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N
# 0  In a future where the elite inhabit an island ... 2020-08-14
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23

# %%
#filtering
data[data['cast'] =='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description, Date_N]
# Index: []

# %%
data[data['cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-8b73098fb4c1> in <module>
# ----> 1 data[data['cast'].str.contains('Tom Cruise')]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3443
#    3444         # Do we have a (boolean) 1d indexer?
# -> 3445         if com.is_bool_indexer(key):
#    3446             return self._getitem_bool_array(key)
#    3447
#
# ~\Anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
#     141             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
data_new = data.dropna() #creating new data frame

# %%
data_new.head(2)
# Out:
#   show_id   type  title           director  \
# 1      s2  Movie   7:19  Jorge Michel Grau
# 2      s3  Movie  23:59       Gilbert Chan
#
#                                                 cast    country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#           date_added  release_year rating duration  \
# 1  December 23, 2016        2016.0  TV-MA   93 min
# 2  December 20, 2018        2018.0      R   78 min
#
#                              listed_in  \
# 1         Dramas, International Movies
# 2  Horror Movies, International Movies
#
#                                          description     Date_N
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23
# 2  When an army recruit is found dead, his fellow... 2018-12-20

# %%
data_new[data_new['cast'].str.contains('Tom Cruise')]
# Out:
#      show_id   type     title              director  \
# 3860   s3861  Movie  Magnolia  Paul Thomas Anderson
# 5070   s5071  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5070  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#            date_added  release_year rating duration  \
# 3860  January 1, 2020        2020.0      R  189 min
# 5070     July 1, 2019        2019.0      R  134 min
#
#                        listed_in  \
# 3860  Dramas, Independent Movies
# 5070      Classic Movies, Dramas
#
#                                             description     Date_N
# 3860  Through chance, human action, past history and... 2020-01-01
# 5070  A fast-talking yuppie is forced to slow down w... 2019-07-01

# %%
#different ratngs defined by Netflix
data['rating'].nunique()
# Out:
# 14

# %%
data['rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
#how many movies got the 'TV-14' rating, in Canada?
data[(data['type'] == 'Movie') & (data['rating'] == 'TV-14')].shape
# Out:
# (1272, 13)

# %%
data[(data['type'] == 'Movie') & (data['rating'] == 'TV-14') & (data['country'] == 'Canada')].shape
# Out:
# (11, 13)

# %%
#how many TV show got 'R' rating after year 2016?
data[(data['type'] == 'TV Show') & (data['rating'] == 'R')]
# Out:
#      show_id     type                                title           director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6435   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6435  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#              date_added  release_year rating  duration  \
# 4497  December 10, 2016        2016.0      R  1 Season
# 6435     April 25, 2019        2019.0      R  1 Season
#
#                                             listed_in  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6435                                         TV Shows
#
#                                             description     Date_N
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10
# ...

# %%
data[(data['type'] == 'TV Show') & (data['rating'] == 'R') & (data['release_year'] > 2016)]
# Out:
#      show_id     type                                title           director  \
# 6435   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country  \
# 6435  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#           date_added  release_year rating  duration listed_in  \
# 6435  April 25, 2019        2019.0      R  1 Season  TV Shows
#
#                                             description     Date_N
# 6435  Trapped at a stagecoach stop as a storm rages ... 2019-04-25

# %%
#How many TV shows got 'R' rating after the year 2018?
data[(data['type']=='TV Show') & (data['rating'] == 'R')]
# Out:
#      show_id     type                                title           director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6435   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6435  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#              date_added  release_year rating  duration  \
# 4497  December 10, 2016        2016.0      R  1 Season
# 6435     April 25, 2019        2019.0      R  1 Season
#
#                                             listed_in  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6435                                         TV Shows
#
#                                             description     Date_N
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10
# ...

# %%
data[(data['type']=='TV Show') & (data['rating'] == 'R') & (data['release_year'] > 2018)]
# Out:
#      show_id     type                                title           director  \
# 6435   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    cast country  \
# 6435  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#           date_added  release_year rating  duration listed_in  \
# 6435  April 25, 2019        2019.0      R  1 Season  TV Shows
#
#                                             description     Date_N
# 6435  Trapped at a stagecoach stop as a storm rages ... 2019-04-25

# %%
#Maximum duration of a movie/show on netflix
data['duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
data.duration.dtypes
# Out:
# dtype('O')

# %%
data[['minutes','unit']] = data['duration'].str.split(' ', expand = True)

# %%
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020        2020.0  TV-MA  4 Seasons
# 1  December 23, 2016        2016.0  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N minutes  \
# 0  In a future where the elite inhabit an island ... 2020-08-14       4
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23      93
#
#       unit
# 0  Seasons
# 1      min

# %%
data['minutes'].max()
# Out:
# '99'

# %%
data['minutes'].min()
# Out:
# '1'

# %%
data['minutes'].mean()
# Out:
# inf

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year           float64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Date_N          datetime64[ns]
# minutes                 object
# unit                    object
# dtype: object

# %%
#which country having highest number of TV shows
data_tvshow = data[data['type'] == 'TV Show']

# %%
data_tvshow.head(2)
# Out:
#   show_id     type title     director  \
# 0      s1  TV Show    3%          NaN
# 5      s6  TV Show    46  Serdar Akar
#
#                                                 cast country       date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey     July 1, 2017
#
#    release_year rating   duration  \
# 0        2020.0  TV-MA  4 Seasons
# 5        2017.0  TV-MA   1 Season
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 5    International TV Shows, TV Dramas, TV Mysteries
#
#                                          description     Date_N minutes  \
# 0  In a future where the elite inhabit an island ... 2020-08-14       4
# 5  A genetics professor experiments with a treatm... 2017-07-01       1
#
#       unit
# 0  Seasons
# 5   Season

# %%
data_tvshow.country.value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: country, Length: 183, dtype: int64

# %%
data_tvshow.country.value_counts().head(1)
# Out:
# United States    705
# Name: country, dtype: int64

# %%
#Sorting dataset by year
data.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020        2020.0  TV-MA  4 Seasons
# 1  December 23, 2016        2016.0  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description     Date_N minutes  \
# 0  In a future where the elite inhabit an island ... 2020-08-14       4
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23      93
#
#       unit
# 0  Seasons
# 1      min

# %%
data.sort_values(by = 'release_year').head(10)
# Out:
#      show_id     type                        title                director  \
# 1765   s1766  TV Show              Dinner for Five                     NaN
# 7113   s7114    Movie         To and From New York    Sorin Dan Mihalcescu
# 3248   s3249    Movie      Just Another Love Story            Ole Bornedal
# 5765   s5766    Movie                     Splatter               Joe Dante
# 3840   s3841    Movie  Mad Ron's Prevues from Hell              Jim Monaco
# 232     s233    Movie   A Stoning in Fulham County           Larry Elikann
# 5832   s5833    Movie               Strange Voices  Arthur Allan Seidelman
# 7149   s7150    Movie           Too Young the Hero              Buzz Kulik
# 308     s309    Movie     Adam: His Song Continues        Robert Markowitz
# 2962   s2963    Movie  In Defense of a Married Man           Joel Oliansky
#
#                                                    cast        country  \
# ...

# %%
data.sort_values(by = 'release_year', ascending = False).head(10)
# Out:
#      show_id   type               title                      director  \
# 7351   s7352  Movie             Unknown            Jaume Collet-Serra
# 2013   s2014  Movie    Enter the Dragon                 Robert Clouse
# 2349   s2350  Movie           Gangaajal                   Prakash Jha
# 1194   s1195  Movie   Can't Hardly Wait  Harry Elfont, Deborah Kaplan
# 1497   s1498  Movie      Cool Hand Luke              Stuart Rosenberg
# 104     s105  Movie  30 Minutes or Less               Ruben Fleischer
# 692     s693  Movie      Bad Grandpa .5                 Jeff Tremaine
# 5138   s5139  Movie          Redemption                 Steven Knight
# 3521   s3522  Movie              Lagaan            Ashutosh Gowariker
# 5520   s5521  Movie  Sex and the City 2          Michael Patrick King
#
#                                                    cast  \
# 7351  Liam Neeson, Diane Kruger, January Jones, Aida...
# 2013  Bruce Lee, John Saxon, Jim Kelly, Ahna Capri, ...
# ...

# %%
#finding all instances where 
#1. category is 'movie' and type is 'dramas'
#2. category is 'TV show' and type is 'dramas'
data[(data['type']=='Movie') & (data['listed_in'] == 'Dramas')]
# Out:
#      show_id   type                       title           director  \
# 4         s5  Movie                          21     Robert Luketic
# 7         s8  Movie                         187     Kevin Reynolds
# 170     s171  Movie                A Family Man      Mark Williams
# 232     s233  Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296  Movie          Across Grace Alley      Ralph Macchio
# ...      ...    ...                         ...                ...
# 7415   s7416  Movie                      Victor  Brandon Dickerson
# 7420   s7421  Movie                     Villain   Philip Barantini
# 7447   s7448  Movie                         VS.           Ed Lilly
# 7463   s7464  Movie                   Wakefield      Robin Swicord
# 7478   s7479  Movie                   War Horse   Steven Spielberg
#
#                                                    cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data[(data['type']=='TV Show') & (data['listed_in'] == 'TV Dramas')]
# Out:
#      show_id     type                                              title  \
# 259     s260  TV Show                            A.D. Kingdom and Empire
# 1802   s1803  TV Show                        Dolly Parton's Heartstrings
# 1900   s1901  TV Show                                            Dynasty
# 2051   s2052  TV Show                                               Evil
# 2457   s2458  TV Show                                            Godless
# 2535   s2536  TV Show                                          Greenleaf
# 2562   s2563  TV Show                                              Gypsy
# 2587   s2588  TV Show                                Halt and Catch Fire
# 2678   s2679  TV Show                                          Heartland
# 2739   s2740  TV Show                                  Highway to Heaven
# 2777   s2778  TV Show                                          Hollywood
# 3401   s3402  TV Show                                            Kingdom
# ...

# %%
data[(data['type']=='Movie') & (data['listed_in'] == 'Dramas') | (data['type']=='TV Show') & (data['listed_in'] == 'TV Dramas')]
# Out:
#      show_id     type                       title          director  \
# 4         s5    Movie                          21    Robert Luketic
# 7         s8    Movie                         187    Kevin Reynolds
# 170     s171    Movie                A Family Man     Mark Williams
# 232     s233    Movie  A Stoning in Fulham County     Larry Elikann
# 259     s260  TV Show     A.D. Kingdom and Empire               NaN
# ...      ...      ...                         ...               ...
# 7420   s7421    Movie                     Villain  Philip Barantini
# 7447   s7448    Movie                         VS.          Ed Lilly
# 7463   s7464    Movie                   Wakefield     Robin Swicord
# 7478   s7479    Movie                   War Horse  Steven Spielberg
# 7578   s7579  TV Show        When Calls the Heart               NaN
#
#                                                    cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
